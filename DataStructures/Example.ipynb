# %%
#ToDo list
to_do_list=["Buy Groceries","Clean house","Pay bills"]

to_do_list.append("Drink water")
to_do_list.append("Exercise")

print(to_do_list)

to_do_list.remove("Drink water")

if "Pay bills" in to_do_list:
    print("Don't forget to pay bills")

for task in to_do_list:
    print(f"--{task}")
# Out:
# ['Buy Groceries', 'Clean house', 'Pay bills', 'Drink water', 'Exercise']
# Don't forget to pay bills
# --Buy Groceries
# --Clean house
# --Pay bills
# --Exercise

# %%
grades=[23,44,56,78,12]

average=sum(grades)/len(grades)

print(average)


print ("max marks are",max(grades))
print ("min marks are",min(grades))
# Out:
# 42.6
# max marks are 78
# min marks are 12

# %%
#Collectiong user feedback
feedback=["Great service","Very nice","Could be better","Excellent experience"]

feedback.append("Not happy with service")

positive_feedback_count=sum(1 for comment in feedback if "great" in comment.lower() or "excellent" in comment.lower())
print(f"positive feedback count :{positive_feedback_count}")

print("user feedback")
for comment in feedback:
    print(f"-{comment}")
# Out:
# positive feedback count :2
# user feedback
# -Great service
# -Very nice
# -Could be better
# -Excellent experience
# -Not happy with service
