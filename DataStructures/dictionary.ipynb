# %%
#Dictionary unordered and key value pair

empty_dict={}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
empty_dict = dict()
empty_dict
# Out:
# {}

# %%
student = {"name": "Krish", "age": 32, "grade": "A"}
print(student)
print(type(student))
# Out:
# {'name': 'Krish', 'age': 32, 'grade': 'A'}
# <class 'dict'>

# %%
student = {"name": "Krish", "age": 32, "name": "A" }
print(student)
# Out:
# {'name': 'A', 'age': 32}

# %%
##accessing Dictionary Elements
student = {"name": "Krish", "age": 32, "grade": "A"}
print(student['grade'])

print(student.get('age'))
print(student.get('last_name'))
print(student.get('last_name', 'Not available'))
# Out:
# A
# 32
# None
# Not available

# %%
#modifying dictionary

student["age"]=33
print(student)
student["address"]="India"
print(student)
# Out:
# {'name': 'Krish', 'age': 33, 'grade': 'A'}
# {'name': 'Krish', 'age': 33, 'grade': 'A', 'address': 'India'}

# %%
del student['grade']
print(student)
# Out:
# {'name': 'Krish', 'age': 33, 'address': 'India'}

# %%
#Dictionary methods

keys=student.keys()
print(keys)
values=student.values()
print(values)


items=student.items()
print(items)
# Out:
# dict_keys(['name', 'age', 'address'])
# dict_values(['Krish', 33, 'India'])
# dict_items([('name', 'Krish'), ('age', 33), ('address', 'India')])

# %%
##shallow copy
student_copy=student
print(student_copy)
print(student)
# Out:
# {'name': 'Krish', 'age': 33, 'address': 'India'}

# %%
student["name"]="Krish1"
print(student)
print(student_copy)
# Out:
# {'name': 'Krish1', 'age': 33, 'address': 'India'}
# {'name': 'Krish1', 'age': 33, 'address': 'India'}

# %%
student_copy1=student.copy()
print(student_copy1)
print(student)
student["name"]="Sia"
print(student_copy1)
print(student)
# Out:
# {'name': 'Krish1', 'age': 33, 'address': 'India'}
# {'name': 'Krish1', 'age': 33, 'address': 'India'}
# {'name': 'Krish1', 'age': 33, 'address': 'India'}
# {'name': 'Sia', 'age': 33, 'address': 'India'}

# %%
#Iterating

for keys in student.keys():
    print(keys)
for values in student.values():
    print(values)
for keys,values in student.items():
    print(keys, values)
# Out:
# name
# age
# address
# Sia
# 33
# India
# name Sia
# age 33
# address India

# %%
#Nested Dictionary
students={
    "student1":{"name":"gian","age":16},
    "student2":{"name":"sonio","age":15}
}
print(students)
# Out:
# {'student1': {'name': 'gian', 'age': 16}, 'student2': {'name': 'sonio', 'age': 15}}

# %%
#access nested dictionaries

print(students['student2']['name'])
print(students['student2']['age'])
# Out:
# sonio
# 15

# %%
students.items()
# Out:
# dict_items([('student1', {'name': 'gian', 'age': 16}), ('student2', {'name': 'sonio', 'age': 15})])

# %%
for student_id,student_info in students.items():
    print(f"{student_id}:{student_info}")
    for keys,values in student_info.items():
        print(f"{keys}:{values}")
# Out:
# student1:{'name': 'gian', 'age': 16}
# name:gian
# age:16
# student2:{'name': 'sonio', 'age': 15}
# name:sonio
# age:15

# %%
#Dictionary Comprehension

squares={x:x**2 for x in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
numbers=[1,2,2,3,3,3,4,4,4,4]
frequency={}

for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %%
#merging

dic1={"a":1,"b":2}
dic2={"b":3,"c":4}
merged_dict={**dic1,**dic2}
print(merged_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}
