# %%
#immutable
empty_tuple=()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
numbers=tuple([1,2,3,4,5,6])
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
lst=list((1,2,3,4,5))
print(list)
print(lst)
# Out:
# <class 'list'>
# [1, 2, 3, 4, 5]

# %%
mixed_tuple=(1,"Hello World",3.14,True)
print(mixed_tuple)
# Out:
# (1, 'Hello World', 3.14, True)

# %%
##Accessing Tuple Elements

numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
numbers[0]
numbers[2]
numbers[-1]
# Out:
# 6

# %%
numbers[0:4]
# Out:
# (1, 2, 3, 4)

# %%
numbers[::-1]
# Out:
# (6, 5, 4, 3, 2, 1)

# %%
concat_tuple=numbers + mixed_tuple
print(concat_tuple)
# Out:
# (1, 2, 3, 4, 5, 6, 1, 'Hello World', 3.14, True)

# %%
mixed_tuple*3
# Out:
# (1,
#  'Hello World',
#  3.14,
#  True,
#  1,
#  'Hello World',
#  3.14,
#  True,
#  1,
#  'Hello World',
#  3.14,
#  True)

# %%
## Immutable nature of tuples

lst=[1,2,3,4,5]
print(lst)

lst[1]="Krish"
print(lst)
# Out:
# [1, 2, 3, 4, 5]
# [1, 'Krish', 3, 4, 5]

# %%
#numbers[1]="Krish"  error

# %%
#Tuple methods

print(numbers.count(1))
print(numbers.index(3))
# Out:
# 1
# 2

# %%
#packing and unpacking tuples

packed_tuple=1,"Hello",3.14
print(packed_tuple)
# Out:
# (1, 'Hello', 3.14)

# %%
#unpacking 

a,b,c=packed_tuple
print(a,b,c)
# Out:
# 1 Hello 3.14

# %%
#Unpacking with star

numbers=(1,2,3,4,5)
first,*middle,last=numbers
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4]
# 5

# %%
##Nested tuple
##Nested list

lst=[[1,2,3,4],[6,7,8,9],[1,"Hello"]]
lst[0][0:3]
# Out:
# [1, 2, 3]

# %%
lst=[[1,2,3,4],[6,7,8,9],(1,"Hello")]
lst[2][0:]
# Out:
# (1, 'Hello')

# %%
nested_tuple=((1,2,3),("a","b","c"),(True,False))

print(nested_tuple[0])
print(nested_tuple[1][2])
# Out:
# (1, 2, 3)
# c

# %%
# Iterating over nested tuple
for sub_tupl in nested_tuple:
    for item in sub_tupl:
        print(item,end=" ")
    print(" ")
# Out:
# 1 2 3
# a b c
# True False
