# %%
#syntax

def function_name(parameters):
    """"Docstring"""
    #Function body
    return expression

# %%
##why function ?

num=24
if num%2==0:
    print("the number is even")
else:
    print("the number is odd")
# Out:
# the number is even

# %%
def even_or_odd(num):
    '''This function finds even or odd'''
    if num%2==0:
        print("the number is even")
    else:
        print("the nummber is odd")

# %%
## Call this function 
even_or_odd(24)
# Out:
# the number is even

# %%
## function with multiple paramenters

def add(a,b):
    return a+b


result=add(2,4)
print(result)

# %%
## default parameters

def greet(name="Heer"):
    print(f" Hello {name} Welcome to the paradise")

greet()
# Out:
#  Hello Heer Welcome to the paradise

# %%
## Variable Length Arguments
## Positional and keywords arguments

def print_numbers(*args):
    for num in args:
        print(num)

# %%
print_numbers(1,2,3,4,5,6.7,8,"Seno")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6.7
# 8
# Seno

# %%
## Keyword arguments

def print_details(**kwargs):
    for key,value in kwargs.items():
        print(f"{key}:{value}")

# %%
print_details(name="krish",age="32",country="India")
# Out:
# name:krish
# age:32
# country:India

# %%
### Return statements
def multiply(a,b):
    return a*b,a

multiply(2,3)
# Out:
# (6, 2)
